# %% [markdown]
# # Welcome to the Second Exercise Session of the NLP Tutoring Course
#
# The main topics of this Colab notebook are **dot product** and **sentiment analysis** 🐶
#
# ## **Contents**
#
# 1. **Dot Product**
#     - **Exercise 1**: Vectorize with Bag of Words and calculate the dot product of the vectors.
#
# 2. **Sentiment Analysis**
#  - **Exercise 2**: Produce sentiment scores and labels for joke reviews.

# %% [markdown]
# Your installs and imports should be here ⬇

# %%
! git clone https://github.com/taivop/joke-dataset.git
# Out:
# Cloning into 'joke-dataset'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 44 (delta 12), reused 10 (delta 10), pack-reused 30 (from 1)
# Receiving objects: 100% (44/44), 32.38 MiB | 9.56 MiB/s, done.
# Resolving deltas: 100% (21/21), done.
# Updating files: 100% (9/9), done.

# %%
! pip3 install vaderSentiment
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 2.2 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from collections import Counter
import re
import nltk
nltk.download('punkt')
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import random
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
# import the dataset as we showed last time
df = pd.read_json('/content/joke-dataset/reddit_jokes.json')

# %% [markdown]
# ## Dot Product
# Exercise 1: Use Bag of Words representations for the 2 random jokes in the dataset and calculate the dot product of the vectors.
#
# **Steps**
#
# 1.   Create a list of tuples with the jokes. The first part of the joke is in the column 'title' of the df, while the punchline is in the 'body'.
# 2.   Preprocess the text as you already know.
# 3.   Create a Bag of Words representation (you might want to combine the two parts of each tuple).
# 4.   Calculate the dot product of the BoW vectors.

# %%
# take a look at the df
df
# Out:
#                                                      body      id  score  \
# 0       Now I have to say "Leroy can you please paint ...  5tz52q      1
# 1       Pizza doesn't scream when you put it in the ov...  5tz4dd      0
# 2       ...and being there really helped me learn abou...  5tz319      0
# 3       A Sunday school teacher is concerned that his ...  5tz2wj      1
# 4       He got caught trying to sell the two books to ...  5tz1pc      0
# ...                                                   ...     ...    ...
# 194548  Gives me something to read while i'm in the sh...  1a89ts      5
# 194549                        I mean dyslexia fcuk!!! >_<  1a87we     12
# 194550       A hockey player showers after three periods.  1a7xnd     44
# 194551  A father buys a lie detector robot that slaps ...  1a813f     63
# 194552                                It was a 'Shih Tzu'  1a801u      0
#
#                                                     title
# ...

# %% [markdown]
# ## Sentiment Analysis
# Exercise 2: Add sentiment scores to the mini dataset.
#
# 1.   Use the starting code to get the mini dataset with the reviews (5 instances).
# 2.   Preprocess the text according to your judgement.
# 3.   Use VADER to produce sentiment scores. Add them in a new column in your dataframe.
# 4.   Make a nice function to translate those scores into sentiments (positive negative neutral).
#
# Try to use functions here :)

# %%
joke_reviews = df.head(5) # I'm keeping only the first 5 rows for the purposes of this exercise.
joke_reviews['reviews'] = ['This is a terrible joke. How is it possible that people can still be so racist?', 'The shocking effect on this one was intense. I cannot believe that anyone is still laughing at those things'\
                           , 'That was not funny', 'Not crazy about this one!', 'That is an excellent joke! It cracked me up!']
# Out:
# <ipython-input-6-ae3d183a76fc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joke_reviews['reviews'] = ['This is a terrible joke. How is it possible that people can still be so racist?', 'The shocking effect on this one was intense. I cannot believe that anyone is still laughing at those things'\

# %% [markdown]
# ## **Playground**
#
#
# *   Can we produce a super negative comment that vader marks as super positive and vica versa?
# * Let's see compare the scores you will produce :)
